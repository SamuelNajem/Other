# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelNajem/Other/blob/main/DSNP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world")
A =3
B = 5
C = A+B
print (C)
We = 34
Us = 7
Them = We/Us
print (Them)
For = 'Fri'
Boo = 'end'
Boss = For + Boo
print (Boss)
# Out:
# hello world
# 8
# 4.857142857142857
# Friend
